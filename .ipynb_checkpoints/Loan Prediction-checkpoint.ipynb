# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import csv data
df = pd.read_csv("train.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ## Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#handle missing data
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())

# %%
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# handling categorical data
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])

# %%
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(df['Gender'])
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df.Dependents)
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.distplot(df.CoapplicantIncome)
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CoapplicantIncome', ylabel='Density'>

# %%
sns.displot(df.LoanAmount)

# %%
sns.distplot(df.Credit_History)
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Credit_History', ylabel='Density'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
# data transformation
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome'])
sns.distplot(df.ApplicantIncomeLog)
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
# dimensionality reduction
df['Total_income'] = df['ApplicantIncome'] + df['CoapplicantIncome']

# %%
# data transformation
df['CoapplicantIncomeLog'] = np.log(df['CoapplicantIncome'])
sns.distplot(df.CoapplicantIncomeLog)
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Sulav\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sulav\anaconda3\lib\site-packages\numpy\lib\function_base.py:3961: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-360-af8aacf8c5cd> in <module>
#       1 # data transformation
#       2 df['CoapplicantIncomeLog'] = np.log(df['CoapplicantIncome'])
# ----> 3 sns.distplot(df.CoapplicantIncomeLog)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2610     if hist:
#    2611         if bins is None:
# -> 2612             bins = min(_freedman_diaconis_bins(a), 50)
#    2613         hist_kws.setdefault("alpha", 0.4)
#    2614         hist_kws.setdefault("density", norm_hist)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#    2401         return int(np.sqrt(a.size))
#    2402     else:
# -> 2403         return int(np.ceil((a.max() - a.min()) / h))
#    2404
#    2405
#
# ValueError: cannot convert float NaN to integer

# %%
df['Total_Income_Log'] = np.log(df['Total_income'])
sns.displot(df["Total_Income_Log"])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  ApplicantIncomeLog  Total_income  \
# 0             1.0         Urban           Y            8.674026        5849.0
# 1             1.0         Rural           N            8.430109        6091.0
# 2             1.0         Urban           Y            8.006368        3000.0
# 3             1.0         Urban           Y            7.856707        4941.0
# 4             1.0         Urban           Y            8.699515        6000.0
#
#    CoapplicantIncomeLog  Total_Income_Log
# 0                  -inf          8.674026
# 1              7.318540          8.714568
# 2                  -inf          8.006368
# 3              7.765569          8.505323
# 4                  -inf          8.699515

# %%
cols = ['Loan_ID','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income','CoapplicantIncomeLog']
df = df.drop(columns=cols, axis=1)

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No          0      Graduate            No             1.0
# 1      Male     Yes          1      Graduate            No             1.0
# 2      Male     Yes          0      Graduate           Yes             1.0
# 3      Male     Yes          0  Not Graduate            No             1.0
# 4      Male      No          0      Graduate            No             1.0
# ..      ...     ...        ...           ...           ...             ...
# 609  Female      No          0      Graduate            No             1.0
# 610    Male     Yes         3+      Graduate            No             1.0
# 611    Male     Yes          1      Graduate            No             1.0
# 612    Male     Yes          2      Graduate            No             1.0
# 613  Female      No          0      Graduate           Yes             0.0
#
#     Property_Area Loan_Status  ApplicantIncomeLog  Total_Income_Log
# 0           Urban           Y            8.674026          8.674026
# 1           Rural           N            8.430109          8.714568
# 2           Urban           Y            8.006368          8.006368
# 3           Urban           Y            7.856707          8.505323
# 4           Urban           Y            8.699515          8.699515
# ..            ...         ...                 ...               ...
# 609         Rural           Y            7.972466          7.972466
# 610         Rural           Y            8.320205          8.320205
# 611         Urban           Y            8.996157          9.025456
# 612         Urban           Y            8.933664          8.933664
# 613     Semiurban           N            8.430109          8.430109
#
# [614 rows x 10 columns]

# %%
df.Gender.value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
df.Education.value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
#handling categorical data
cat_cols = ['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status','Dependents']
cat_cols
# Out:
# ['Gender',
#  'Married',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status',
#  'Dependents']

# %%
for col in cat_cols:
    df[col] = pd.get_dummies(df[col],drop_first=True)

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomeLog  Total_Income_Log
# 0              0            1            8.674026          8.674026
# 1              0            0            8.430109          8.714568
# 2              0            1            8.006368          8.006368
# 3              0            1            7.856707          8.505323
# 4              0            1            8.699515          8.699515

# %% [markdown]
# ## for testing data

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# 3             NaN         Urban
# 4             1.0         Urban

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
test_df.tail()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural

# %%
test_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
test_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# handling missing numerical data
test_df['LoanAmount'] = test_df['LoanAmount'].fillna(test_df['LoanAmount'].mean())
test_df['Loan_Amount_Term'] = test_df['Loan_Amount_Term'].fillna(test_df['Loan_Amount_Term'].mean())
test_df['Credit_History'] = test_df['Credit_History'].fillna(test_df['Credit_History'].mean())

# %%
test_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0        1.000000         Urban
# 1        1.000000         Urban
# 2        1.000000         Urban
# 3        0.825444         Urban
# 4        1.000000         Urban

# %%
# handling missing categorical data
test_df['Gender'] = test_df['Gender'].fillna(test_df['Gender'].mode()[0])
test_df['Married'] = test_df['Married'].fillna(test_df['Married'].mode()[0])
test_df['Dependents'] = test_df['Dependents'].fillna(test_df['Dependents'].mode()[0])

test_df['Education'] = test_df['Education'].fillna(test_df['Education'].mode()[0])
test_df['Self_Employed'] = test_df['Self_Employed'].fillna(test_df['Self_Employed'].mode()[0])
test_df['Property_Area'] = test_df['Property_Area'].fillna(test_df['Property_Area'].mode()[0])

# %%
test_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test_df['Total_income'] = test_df['ApplicantIncome'] + test_df['CoapplicantIncome']

# %%
test_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  Total_income
# 0        1.000000         Urban          5720
# 1        1.000000         Urban          4576
# 2        1.000000         Urban          6800
# 3        0.825444         Urban          4886
# 4        1.000000         Urban          3276

# %%
#applying log transformation
test_df['ApplicantIncomeLog'] = np.log(test_df['ApplicantIncome'])
test_df['CoapplicantIncomeLog'] = np.log(test_df['CoapplicantIncome'])
test_df['LoanAmountLog'] = np.log(test_df['LoanAmount'])
test_df['Loan_Amount_Term_Log'] = np.log(test_df['Loan_Amount_Term'])
test_df['Total_Income_Log'] = np.log(test_df['Total_income'])
# Out:
# C:\Users\Sulav\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
test_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  Total_income  ApplicantIncomeLog  \
# 0        1.000000         Urban          5720            8.651724
# 1        1.000000         Urban          4576            8.031385
# 2        1.000000         Urban          6800            8.517193
# 3        0.825444         Urban          4886            7.757906
# 4        1.000000         Urban          3276            8.094378
#
#    CoapplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  Total_Income_Log
# 0                  -inf       4.700480              5.886104          8.651724
# 1              7.313220       4.836282              5.886104          8.428581
# 2              7.495542       5.337538              5.886104          8.824678
# 3              7.842279       4.605170              5.886104          8.494129
# 4                  -inf       4.356709              5.886104          8.094378

# %%
cols = ['Loan_ID','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income','CoapplicantIncomeLog']
test_df = test_df.drop(columns = cols, axis=1)

# %%
cols = ['Gender','Married','Education','Self_Employed','Property_Area','Dependents']
for col in cols:
    test_df[col] = pd.get_dummies(test_df[col], drop_first=True)

# %%
test_df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        1           0          0              0        1.000000
# 1       1        1           1          0              0        1.000000
# 2       1        1           0          0              0        1.000000
# 3       1        1           0          0              0        0.825444
# 4       1        0           0          1              0        1.000000
#
#    Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0              0            8.651724       4.700480              5.886104
# 1              0            8.031385       4.836282              5.886104
# 2              0            8.517193       5.337538              5.886104
# 3              0            7.757906       4.605170              5.886104
# 4              0            8.094378       4.356709              5.886104
#
#    Total_Income_Log
# 0          8.651724
# 1          8.428581
# 2          8.824678
# 3          8.494129
# 4          8.094378

# %%
test_df.tail()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 362       1        1           0          1              1        1.000000
# 363       1        1           0          0              0        1.000000
# 364       1        0           0          0              0        0.825444
# 365       1        1           0          0              0        1.000000
# 366       1        0           0          0              1        1.000000
#
#      Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 362              0            8.296297       4.727388              5.886104
# 363              0            8.332789       4.744932              5.886104
# 364              1            8.086410       4.836282              5.886104
# 365              0            8.517193       5.062595              5.886104
# 366              0            9.126959       4.584967              5.192957
#
#      Total_Income_Log
# 362          8.663196
# 363          8.490233
# 364          8.564649
# 365          8.908289
# 366          9.126959

# %% [markdown]
# ## train the model

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomeLog  Total_Income_Log
# 0              0            1            8.674026          8.674026
# 1              0            0            8.430109          8.714568
# 2              0            1            8.006368          8.006368
# 3              0            1            7.856707          8.505323
# 4              0            1            8.699515          8.699515

# %%
# specifying input and output attributes
x = df.drop(columns = ['Loan_Status'], axis=1)
y = df['Loan_Status']

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           0          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           0          0              0             1.0
# 613       0        0           0          0              1             0.0
#
#      Property_Area  ApplicantIncomeLog  Total_Income_Log
# 0                0            8.674026          8.674026
# 1                0            8.430109          8.714568
# 2                0            8.006368          8.006368
# 3                0            7.856707          8.505323
# 4                0            8.699515          8.699515
# ..             ...                 ...               ...
# 609              0            7.972466          7.972466
# 610              0            8.320205          8.320205
# 611              0            8.996157          9.025456
# 612              0            8.933664          8.933664
# 613              1            8.430109          8.430109
#
# [614 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: uint8

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25, random_state=42)

# %%
x_train.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 92        1        1           0          1              0             1.0
# 304       1        0           0          0              0             1.0
# 68        1        1           0          1              1             1.0
# 15        1        0           0          0              0             1.0
# 211       1        1           0          0              0             0.0
#
#      Property_Area  ApplicantIncomeLog  Total_Income_Log
# 92               0            8.093462          8.535622
# 304              0            8.294050          8.779557
# 68               0            8.867850          8.867850
# 15               0            8.507143          8.507143
# 211              1            8.140316          8.451053

# %%
x_test.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 350       1        1           0          0              0        1.000000
# 377       1        1           0          0              0        0.842199
# 163       1        1           0          0              0        1.000000
# 609       0        0           0          0              0        1.000000
# 132       1        0           0          0              0        1.000000
#
#      Property_Area  ApplicantIncomeLog  Total_Income_Log
# 350              1            9.114160          9.114160
# 377              1            8.368693          8.368693
# 163              0            8.334952          8.633019
# 609              0            7.972466          7.972466
# 132              1            7.907652          7.907652

# %%
# randomforest classifier
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(x_test, y_test) * 100
# Out:
# 73.37662337662337

# %%
# using decision tree classifier
from sklearn.tree import DecisionTreeClassifier
dtc_model = DecisionTreeClassifier()
dtc_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc_model.score(x_test,y_test)*100
# Out:
# 68.83116883116884

# %%
# using logistic regression
from sklearn.linear_model import LogisticRegression
lm_model = LogisticRegression()
lm_model.fit(x_test,y_test)
# Out:
# LogisticRegression()

# %%
lm_model.score(x_test,y_test)*100
# Out:
# 77.27272727272727

# %% [markdown]
# ## confusion matrix

# %%
#random forest classifier
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[21, 33],
#        [ 8, 92]], dtype=int64)
